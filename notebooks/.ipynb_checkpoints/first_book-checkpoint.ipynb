# %% [markdown]
# OK

# %%
# %run 3D_beam_depo_combine.py
# Out:
# WARNING: none_check returned True (LOCUST_input_type=beam_deposition, ID=fully-combined beam deposition): read_data requires data_format, blank input initialised
#
# birth_157418_ec_0_combined_spiral_100k_wresp_0.dat
# reading beam deposition from SPIRAL full orbit format
# finished reading beam deposition from SPIRAL full orbit format
# birth_157418_ec_0_combined_spiral_100k_wresp_1.dat
# reading beam deposition from SPIRAL full orbit format
# finished reading beam deposition from SPIRAL full orbit format
# birth_157418_ec_0_combined_spiral_100k_wresp_2.dat
# reading beam deposition from SPIRAL full orbit format
# finished reading beam deposition from SPIRAL full orbit format
# birth_157418_ec_0_combined_spiral_100k_wresp_3.dat
# reading beam deposition from SPIRAL full orbit format
# finished reading beam deposition from SPIRAL full orbit format
# birth_157418_ec_0_combined_spiral_100k_wresp_4.dat
# reading beam deposition from SPIRAL full orbit format
# ...
